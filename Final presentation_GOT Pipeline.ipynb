# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Extract the data
df = pd.read_csv("GOT_data/battles.csv")

df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                38 non-null     object
#  1   year                38 non-null     int64
#  2   battle_number       38 non-null     int64
#  3   attacker_king       36 non-null     object
#  4   defender_king       35 non-null     object
#  5   attacker_1          38 non-null     object
#  6   attacker_2          10 non-null     object
#  7   attacker_3          3 non-null      object
#  8   attacker_4          2 non-null      object
#  9   defender_1          37 non-null     object
#  10  defender_2          2 non-null      object
#  11  defender_3          0 non-null      float64
#  12  defender_4          0 non-null      float64
#  13  attacker_outcome    37 non-null     object
#  14  battle_type         37 non-null     object
#  15  major_death         37 non-null     float64
#  16  major_capture       37 non-null     float64
#  17  attacker_size       24 non-null     float64
#  18  defender_size       19 non-null     float64
#  19  attacker_commander  37 non-null     object
#  20  defender_commander  28 non-null     object
#  21  summer              37 non-null     float64
#  22  location            37 non-null     object
#  23  region              38 non-null     object
#  24  note                5 non-null      object
# dtypes: float64(7), int64(2), object(16)
# memory usage: 7.6+ KB

# %%
# Transform the data
# Create a new dataset with the selected columns required for the data analysis
battles = df[['name', 'year', 'attacker_king', 'defender_king', 'attacker_outcome', 'attacker_size', 'defender_size']]
battles
# Out:
#                                                  name  year  \
# 0                          Battle of the Golden Tooth   298
# 1                         Battle at the Mummer's Ford   298
# 2                                  Battle of Riverrun   298
# 3                            Battle of the Green Fork   298
# 4                       Battle of the Whispering Wood   298
# 5                                 Battle of the Camps   298
# 6                                       Sack of Darry   298
# 7                               Battle of Moat Cailin   299
# 8                            Battle of Deepwood Motte   299
# 9                           Battle of the Stony Shore   299
# 10                         Battle of Torrhen's Square   299
# 11                               Battle of Winterfell   299
# 12                           Sack of Torrhen's Square   299
# 13                                 Sack of Winterfell   299
# 14                                  Battle of Oxcross   299
# 15                               Siege of Storm's End   299
# 16                                Battle of the Fords   299
# 17                                  Sack of Harrenhal   299
# 18                                 Battle of the Crag   299
# 19                           Battle of the Blackwater   299
# 20                                     Siege of Darry   299
# 21                               Battle of Duskendale   299
# 22                       Battle of the Burning Septry   299
# 23                            Battle of the Ruby Ford   299
# 24                              Retaking of Harrenhal   299
# 25                                    The Red Wedding   299
# 26                                   Siege of Seagard   299
# 27                             Battle of Castle Black   300
# 28                                Fall of Moat Cailin   300
# 29                                   Sack of Saltpans   300
# 30                         Retaking of Deepwood Motte   300
# 31                       Battle of the Shield Islands   300
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...   300
# 33                        Second Seige of Storm's End   300
# 34                               Siege of Dragonstone   300
# 35                                  Siege of Riverrun   300
# 36                                 Siege of Raventree   300
# 37                                Siege of Winterfell   300
#
#                attacker_king             defender_king attacker_outcome  \
# 0   Joffrey/Tommen Baratheon                Robb Stark              win
# 1   Joffrey/Tommen Baratheon                Robb Stark              win
# 2   Joffrey/Tommen Baratheon                Robb Stark              win
# 3                 Robb Stark  Joffrey/Tommen Baratheon             loss
# 4                 Robb Stark  Joffrey/Tommen Baratheon              win
# 5                 Robb Stark  Joffrey/Tommen Baratheon              win
# 6   Joffrey/Tommen Baratheon                Robb Stark              win
# 7        Balon/Euron Greyjoy                Robb Stark              win
# 8        Balon/Euron Greyjoy                Robb Stark              win
# 9        Balon/Euron Greyjoy                Robb Stark              win
# 10                Robb Stark       Balon/Euron Greyjoy              win
# 11       Balon/Euron Greyjoy                Robb Stark              win
# 12       Balon/Euron Greyjoy       Balon/Euron Greyjoy              win
# 13  Joffrey/Tommen Baratheon                Robb Stark              win
# 14                Robb Stark  Joffrey/Tommen Baratheon              win
# 15         Stannis Baratheon           Renly Baratheon              win
# 16  Joffrey/Tommen Baratheon                Robb Stark             loss
# 17                Robb Stark  Joffrey/Tommen Baratheon              win
# 18                Robb Stark  Joffrey/Tommen Baratheon              win
# 19         Stannis Baratheon  Joffrey/Tommen Baratheon             loss
# 20                Robb Stark  Joffrey/Tommen Baratheon              win
# 21                Robb Stark  Joffrey/Tommen Baratheon             loss
# 22                       NaN                       NaN              win
# 23  Joffrey/Tommen Baratheon                Robb Stark              win
# 24  Joffrey/Tommen Baratheon                       NaN              win
# 25  Joffrey/Tommen Baratheon                Robb Stark              win
# 26                Robb Stark  Joffrey/Tommen Baratheon              win
# 27         Stannis Baratheon              Mance Rayder             loss
# 28  Joffrey/Tommen Baratheon       Balon/Euron Greyjoy              win
# 29                       NaN                       NaN              win
# 30         Stannis Baratheon       Balon/Euron Greyjoy              win
# 31       Balon/Euron Greyjoy  Joffrey/Tommen Baratheon              win
# 32       Balon/Euron Greyjoy  Joffrey/Tommen Baratheon              win
# 33  Joffrey/Tommen Baratheon         Stannis Baratheon              win
# 34  Joffrey/Tommen Baratheon         Stannis Baratheon              win
# 35  Joffrey/Tommen Baratheon                Robb Stark              win
# 36  Joffrey/Tommen Baratheon                Robb Stark              win
# 37         Stannis Baratheon  Joffrey/Tommen Baratheon              NaN
#
#     attacker_size  defender_size
# 0         15000.0         4000.0
# 1             NaN          120.0
# 2         15000.0        10000.0
# 3         18000.0        20000.0
# 4          1875.0         6000.0
# 5          6000.0        12625.0
# 6             NaN            NaN
# 7             NaN            NaN
# 8          1000.0            NaN
# 9           264.0            NaN
# 10          244.0          900.0
# 11           20.0            NaN
# 12            NaN            NaN
# 13          618.0         2000.0
# 14         6000.0        10000.0
# 15         5000.0        20000.0
# 16        20000.0        10000.0
# 17          100.0          100.0
# 18         6000.0            NaN
# 19        21000.0         7250.0
# 20            NaN            NaN
# 21         3000.0            NaN
# 22            NaN            NaN
# 23            NaN         6000.0
# 24            NaN            NaN
# 25         3500.0         3500.0
# 26            NaN            NaN
# 27       100000.0         1240.0
# 28            NaN            NaN
# 29            NaN            NaN
# 30         4500.0          200.0
# 31            NaN            NaN
# 32            NaN            NaN
# 33            NaN          200.0
# 34         2000.0            NaN
# 35         3000.0            NaN
# 36         1500.0            NaN
# 37         5000.0         8000.0

# %%
# Checking null values
battles.isnull().sum()
# Out:
# name                 0
# year                 0
# attacker_king        2
# defender_king        3
# attacker_outcome     1
# attacker_size       14
# defender_size       19
# dtype: int64

# %%
# Replace all null values
battles = battles.copy()
battles.fillna({'attacker_king': 'No King'}, inplace=True)
battles.fillna({'defender_king':'No King'},inplace=True)
battles.fillna({'attacker_outcome':'loss'},inplace=True)

battles.isnull().sum()
# Out:
# name                 0
# year                 0
# attacker_king        0
# defender_king        0
# attacker_outcome     0
# attacker_size       14
# defender_size       19
# dtype: int64

# %%
# Replace the null values to the average (attacker_size)
attacker_size_sum=battles.attacker_size.sum()
average=attacker_size_sum/38
average
# Out:
# 6279.5

# %%
battles.fillna({'attacker_size':6280},inplace=True)

# %%
# Replace the null values to the average (defender_size)
defender_size_sum=battles.defender_size.sum()
average=defender_size_sum/38
average
# Out:
# 3214.0789473684213

# %%
battles.fillna({'defender_size':3214},inplace=True)

# %%
# Change the datatype for analyzing
battles['attacker_size'] = battles['attacker_size'].apply(int)
battles['defender_size'] = battles['defender_size'].apply(int)
battles.dtypes
# Out:
# name                object
# year                 int64
# attacker_king       object
# defender_king       object
# attacker_outcome    object
# attacker_size        int64
# defender_size        int64
# dtype: object

# %%
# Load the data
battles.to_csv("GOT_data/battles_cleaned.csv")

# %%
battles = pd.read_csv("GOT_data/battles_cleaned.csv")
battles
# Out:
#     Unnamed: 0                                               name  year  \
# 0            0                         Battle of the Golden Tooth   298
# 1            1                        Battle at the Mummer's Ford   298
# 2            2                                 Battle of Riverrun   298
# 3            3                           Battle of the Green Fork   298
# 4            4                      Battle of the Whispering Wood   298
# 5            5                                Battle of the Camps   298
# 6            6                                      Sack of Darry   298
# 7            7                              Battle of Moat Cailin   299
# 8            8                           Battle of Deepwood Motte   299
# 9            9                          Battle of the Stony Shore   299
# 10          10                         Battle of Torrhen's Square   299
# 11          11                               Battle of Winterfell   299
# 12          12                           Sack of Torrhen's Square   299
# 13          13                                 Sack of Winterfell   299
# 14          14                                  Battle of Oxcross   299
# 15          15                               Siege of Storm's End   299
# 16          16                                Battle of the Fords   299
# 17          17                                  Sack of Harrenhal   299
# 18          18                                 Battle of the Crag   299
# 19          19                           Battle of the Blackwater   299
# 20          20                                     Siege of Darry   299
# 21          21                               Battle of Duskendale   299
# 22          22                       Battle of the Burning Septry   299
# 23          23                            Battle of the Ruby Ford   299
# 24          24                              Retaking of Harrenhal   299
# 25          25                                    The Red Wedding   299
# 26          26                                   Siege of Seagard   299
# 27          27                             Battle of Castle Black   300
# 28          28                                Fall of Moat Cailin   300
# 29          29                                   Sack of Saltpans   300
# 30          30                         Retaking of Deepwood Motte   300
# 31          31                       Battle of the Shield Islands   300
# 32          32  Invasion of Ryamsport, Vinetown, and Starfish ...   300
# 33          33                        Second Seige of Storm's End   300
# 34          34                               Siege of Dragonstone   300
# 35          35                                  Siege of Riverrun   300
# 36          36                                 Siege of Raventree   300
# 37          37                                Siege of Winterfell   300
#
#                attacker_king             defender_king attacker_outcome  \
# 0   Joffrey/Tommen Baratheon                Robb Stark              win
# 1   Joffrey/Tommen Baratheon                Robb Stark              win
# 2   Joffrey/Tommen Baratheon                Robb Stark              win
# 3                 Robb Stark  Joffrey/Tommen Baratheon             loss
# 4                 Robb Stark  Joffrey/Tommen Baratheon              win
# 5                 Robb Stark  Joffrey/Tommen Baratheon              win
# 6   Joffrey/Tommen Baratheon                Robb Stark              win
# 7        Balon/Euron Greyjoy                Robb Stark              win
# 8        Balon/Euron Greyjoy                Robb Stark              win
# 9        Balon/Euron Greyjoy                Robb Stark              win
# 10                Robb Stark       Balon/Euron Greyjoy              win
# 11       Balon/Euron Greyjoy                Robb Stark              win
# 12       Balon/Euron Greyjoy       Balon/Euron Greyjoy              win
# 13  Joffrey/Tommen Baratheon                Robb Stark              win
# 14                Robb Stark  Joffrey/Tommen Baratheon              win
# 15         Stannis Baratheon           Renly Baratheon              win
# 16  Joffrey/Tommen Baratheon                Robb Stark             loss
# 17                Robb Stark  Joffrey/Tommen Baratheon              win
# 18                Robb Stark  Joffrey/Tommen Baratheon              win
# 19         Stannis Baratheon  Joffrey/Tommen Baratheon             loss
# 20                Robb Stark  Joffrey/Tommen Baratheon              win
# 21                Robb Stark  Joffrey/Tommen Baratheon             loss
# 22                   No King                   No King              win
# 23  Joffrey/Tommen Baratheon                Robb Stark              win
# 24  Joffrey/Tommen Baratheon                   No King              win
# 25  Joffrey/Tommen Baratheon                Robb Stark              win
# 26                Robb Stark  Joffrey/Tommen Baratheon              win
# 27         Stannis Baratheon              Mance Rayder             loss
# 28  Joffrey/Tommen Baratheon       Balon/Euron Greyjoy              win
# 29                   No King                   No King              win
# 30         Stannis Baratheon       Balon/Euron Greyjoy              win
# 31       Balon/Euron Greyjoy  Joffrey/Tommen Baratheon              win
# 32       Balon/Euron Greyjoy  Joffrey/Tommen Baratheon              win
# 33  Joffrey/Tommen Baratheon         Stannis Baratheon              win
# 34  Joffrey/Tommen Baratheon         Stannis Baratheon              win
# 35  Joffrey/Tommen Baratheon                Robb Stark              win
# 36  Joffrey/Tommen Baratheon                Robb Stark              win
# 37         Stannis Baratheon  Joffrey/Tommen Baratheon             loss
#
#     attacker_size  defender_size
# 0           15000           4000
# 1            6280            120
# 2           15000          10000
# 3           18000          20000
# 4            1875           6000
# 5            6000          12625
# 6            6280           3214
# 7            6280           3214
# 8            1000           3214
# 9             264           3214
# 10            244            900
# 11             20           3214
# 12           6280           3214
# 13            618           2000
# 14           6000          10000
# 15           5000          20000
# 16          20000          10000
# 17            100            100
# 18           6000           3214
# 19          21000           7250
# 20           6280           3214
# 21           3000           3214
# 22           6280           3214
# 23           6280           6000
# 24           6280           3214
# 25           3500           3500
# 26           6280           3214
# 27         100000           1240
# 28           6280           3214
# 29           6280           3214
# 30           4500            200
# 31           6280           3214
# 32           6280           3214
# 33           6280            200
# 34           2000           3214
# 35           3000           3214
# 36           1500           3214
# 37           5000           8000
